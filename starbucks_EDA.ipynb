# %%
import pandas as pd
import numpy as np

# %%
sb=pd.read_csv('directory.csv')
sb

As of February 2017: 25600 stores
    
    (22 months later)
As of December 2018: 29144 stores   (but this dataset doesn't have store number)
    
    (24 months later)
As of December 2021: 28289 stores
    
#source: https://www.kaggle.com/datasets/starbucks/store-locations/discussion
# Out:
#            Brand  Store Number        Store Name Ownership Type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# ...

# %%
sb.isnull().sum().sum()
# Out:
# 8402

# %%
sb.columns
# Out:
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Postcode',
#        'Phone Number', 'Timezone', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
sb['Country'].value_counts()
# Out:
# US    13608
# CN     2734
# CA     1468
# JP     1237
# KR      993
#       ...
# CW        3
# AW        3
# MC        2
# LU        2
# AD        1
# Name: Country, Length: 73, dtype: int64

# %%
#postcode and phone number check NaNs

#code to show percentage of nans by column...

percent_missing = sb.isnull().sum() * 100 / len(starbucks)

# %%
percent_missing

#27% NaNs in Phone Number, let's drop it. Don't see a use for phone numbers
# Out:
# Brand              0.000000
# Store Number       0.000000
# Store Name         0.000000
# Ownership Type     0.000000
# Street Address     0.007812
# City               0.058594
# State/Province     0.000000
# Country            0.000000
# Postcode           5.945312
# Phone Number      26.800781
# Timezone           0.000000
# Longitude          0.003906
# Latitude           0.003906
# dtype: float64

# %% [markdown]
# #### Dropping the phone number column

# %%
sb = sb.drop(['Phone Number'], axis=1)
sb
# Out:
#            Brand  Store Number        Store Name Ownership Type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# ...

# %% [markdown]
# #### Standardize the headings

# %%
lower = []
for i in sb.columns:
        lower.append(i.lower())
sb.columns = lower

sb
# Out:
#            brand  store number        store name ownership type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           street address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# ...

# %%
#Puts underscore instead of spaces
under_ = []
for i in sb.columns:
        if ' ' in i:
            under_.append(i.replace(' ', '_'))
        else:
            under_.append(i)
sb.columns = under_   
sb
# Out:
#            brand  store_number        store_name ownership_type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           street_address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# ...

# %%
sb.rename(columns = {'state/province':'state_province'}, inplace = True)
sb
# Out:
#            brand  store_number        store_name ownership_type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           street_address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# ...

# %%
#### Let's look at number of unique values in each column

for col in sb:
    print(len(sb[col].unique()))
# Out:
# 4
# 25599
# 25364
# 4
# 25354
# 5470
# 338
# 73
# 18888
# 101
# 6835
# 3771

# %%
sb['store_name'].nunique()  #store name is basically its own index, should be dropped?
# Out:
# 25364

# %%
sb['store_number'].nunique()   #store number is basically its own index, should be dropped?
# Out:
# 25599

# %%
sb['ownership_type'].value_counts()   #could be interesting to keep this info for later
# Out:
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: ownership_type, dtype: int64

# %%
sb['brand'].value_counts()   #could be interesting to keep this info for later.

#look into what are evolution fresh and coffee house holdings
# Out:
# Starbucks                25249
# Teavana                    348
# Evolution Fresh              2
# Coffee House Holdings        1
# Name: brand, dtype: int64

# %%
sb['street_address'].value_counts()   
#weird that some street addresses are repeated, shouldn't these all be unique values?
#do I really need street address AND lat/long? what does Tableau use?
# Out:
# Circular Building #6, Guard Post 8        11
# 2580 S 156th St                            7
# Stationsplein                              5
# 4100 George J Bean Pkwy                    5
# 5757 Wayne Newton Blvd                     5
#                                           ..
# 1426 Suwan-Dong, Gwangsan-Gu               1
# 107, Hwanggeum-dong, Dong-gu               1
# 1176-3, Chipyeong-Dong, Seo-Gu, 1F         1
# 1240-6 Chipyeong-Dong, Seo-Gu              1
# Shop 2077, Upper Level, Waterfall City     1
# Name: street_address, Length: 25353, dtype: int64

# %%
sb['city'].value_counts()
# Out:
# 上海市              542
# Seoul            243
# 北京市              234
# New York         232
# London           216
#                 ...
# Tepebasi           1
# Isparta            1
# Mersin (Icel)      1
# Mersin Icel        1
# Midrand            1
# Name: city, Length: 5469, dtype: int64

# %%
sb[sb['store_number'] == '9190-180604']
# Out:
#            brand store_number store_name ownership_type      street_address  \
# 10495  Starbucks  9190-180604      Plaza  Joint Venture  ul. Drużbickiego 2
#
#          city state_province country postcode                timezone  \
# 10495  Poznań             WP      PL   61-693  GMT+1:00 Europe/Warsaw
#
#        longitude  latitude
# 10495      16.92     52.44

# %%
sb['brand'].value_counts()
# Out:
# Starbucks                25249
# Teavana                    348
# Evolution Fresh              2
# Coffee House Holdings        1
# Name: brand, dtype: int64

# %%
sb['ownership_type'].value_counts()
# Out:
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: ownership_type, dtype: int64

# %%
Both dataframes need to have same columns and same style
-store number (like 2nd index)
-ownership type
-street_address
-city
-country 
-latitude
-longitude
